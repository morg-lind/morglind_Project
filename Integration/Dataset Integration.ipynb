# %% [markdown]
# ### Project Data Integration

# %%
import pandas as pd 
import numpy as np

# %%
# open the cleaned crime data csv file 
la_crime_data = pd.read_csv("cleaned_crime_data.csv", encoding="utf-8", sep=",", low_memory=False)

la_crime_data.head()
# Out:
#        DR_NO   DATE_RPTD    DATE_OCC  AREA    AREA_NAME  RPT_DIST_NO  CRM_CD  \
# 0  250504239  2025-03-13  2025-03-13     5       Harbor          516     510
# 1  250504238  2025-03-13  2025-03-13     5       Harbor          569     440
# 2  250304275  2025-03-13  2025-03-13     3    Southwest          338     510
# 3  251000503  2025-03-13  2025-03-13    10  West Valley         1035     624
# 4  251700501  2025-03-13  2025-03-13    17   Devonshire         1717     930
#
#                               CRM_CD_DESC                   MOCODES VICT_AGE  \
# 0                        VEHICLE - STOLEN                   Unknown        X
# 1      THEFT PLAIN - PETTY ($950 & UNDER)                   Unknown        X
# 2                        VEHICLE - STOLEN                   Unknown        X
# 3                BATTERY - SIMPLE ASSAULT  0913 1815 1251 0400 0416       16
# 4  CRIMINAL THREATS - NO WEAPON DISPLAYED       0340 0359 1822 1259       16
#
#   VICT_SEX VICT_DESCENT PREMIS_CD  PREMIS_DESC       WEAPON_USED_CD  \
# 0        X            X     108.0  PARKING LOT  Unknown / None Used
# 1        X            X     101.0       STREET  Unknown / None Used
# 2        X            X     101.0       STREET  Unknown / None Used
# 3        M            H     721.0  HIGH SCHOOL                400.0
# 4        M            H     101.0       STREET                511.0
#
#                                       WEAPON_DESC STATUS  STATUS_DESC  \
# 0                             Unknown / None Used     IC  Invest Cont
# 1                             Unknown / None Used     IC  Invest Cont
# 2                             Unknown / None Used     IC  Invest Cont
# 3  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 4                                   VERBAL THREAT     IC  Invest Cont
#
#                                    LOCATION
# 0   1300 N  FRIES                        AV
# 1                                  BERTH 73
# 2   3100    MCCLINTOCK                   AV
# 3  18200    KITTRIDGE                    ST
# 4  11200    GOTHIC                       AV

# %%
la_crime_data.shape
# Out:
# (127826, 19)

# %%
la_crime_data.dtypes
# Out:
# DR_NO              int64
# DATE_RPTD         object
# DATE_OCC          object
# AREA               int64
# AREA_NAME         object
# RPT_DIST_NO        int64
# CRM_CD             int64
# CRM_CD_DESC       object
# MOCODES           object
# VICT_AGE          object
# VICT_SEX          object
# VICT_DESCENT      object
# PREMIS_CD         object
# PREMIS_DESC       object
# WEAPON_USED_CD    object
# WEAPON_DESC       object
# STATUS            object
# STATUS_DESC       object
# LOCATION          object
# dtype: object

# %%
# open the la population csv 
la_population = pd.read_csv("total_la_population.csv", encoding="utf-8", sep=",")

la_population.head(15)
# Out:
#                 Neighborhood American Indian and Alaska Native    Asian  \
# 0               City of L.A.                            44,777  463,960
# 1            Adams-Normandie                               129      394
# 2                     Arleta                               452    4,430
# 3          Arlington Heights                               121    1,919
# 4             Arlington Park                                68       32
# 5            Atwater Village                                41    2,129
# 6              Baldwin Hills                               216      535
# 7                    Bel Air                                 3      972
# 8              Beverly Crest                                 0      301
# 9               Beverly Glen                                 0      431
# 10               Beverlywood                                 0      789
# 11             Boyle Heights                             1,772    2,255
# 12                 Brentwood                                62    2,735
# 13       Broadway-Manchester                                88       32
# 14  Byzantine-Latino Quarter                               375    3,348
#
#    African American Native Hawaiian and Other Pacific Islander      White  \
# 0           328,445                                      5,627  1,092,687
# 1               783                                         63        663
# 2               181                                         46      2,958
# 3             2,293                                          0        744
# 4             1,169                                          0        122
# 5               113                                          0      3,953
# 6            13,592                                         67      2,122
# 7               242                                          0      5,382
# 8               135                                          0      4,668
# 9                45                                          0      2,741
# 10              354                                          0      2,918
# 11            1,047                                         26      2,273
# 12              381                                         55     25,380
# 13            2,451                                          0         87
# 14              621                                         50        848
#
#    Some Other Race Two or More Races Hispanic or Latino
# 0          967,895           607,324          1,822,163
# 1            2,673               944              4,783
# 2           12,733             7,266             25,861
# 3            5,048             1,755              8,195
# 4              929                95              1,508
# 5            2,075             1,278              3,238
# 6            4,224             3,546              8,433
# 7              109               576                370
# 8               36               405                258
# 9               84               559                447
# 10              87               430                521
# 11          56,200            12,298             79,855
# 12             518             3,514              3,000
# 13           4,894             3,077              9,620
# 14           9,010             3,899             15,419

# %%
total_sum = [
    'American Indian and Alaska Native',
    'Asian',
    'African American',
    'Native Hawaiian and Other Pacific Islander',
    'White',
    'Some Other Race',
    'Two or More Races',
    'Hispanic or Latino'
]

# Remove commas and convert to integers
la_population[total_sum] = la_population[total_sum].replace({',': ''}, regex=True).astype(int)

# Sum across the specified columns row-wise
la_population['Total Population'] = la_population[total_sum].sum(axis=1)

# %%
la_population.shape
# Out:
# (152, 9)

# %%
la_population.dtypes
# Out:
# Neighborhood                                  object
# American Indian and Alaska Native             object
# Asian                                         object
# African American                              object
# Native Hawaiian and Other Pacific Islander    object
# White                                         object
# Some Other Race                               object
# Two or More Races                             object
# Hispanic or Latino                            object
# dtype: object

# %%
la_crime_data_cols = la_crime_data.columns
la_population_cols = la_population.columns

print(la_crime_data_cols)
print(la_population_cols)
# Out:
# Index(['DR_NO', 'DATE_RPTD', 'DATE_OCC', 'AREA', 'AREA_NAME', 'RPT_DIST_NO',
#        'CRM_CD', 'CRM_CD_DESC', 'MOCODES', 'VICT_AGE', 'VICT_SEX',
#        'VICT_DESCENT', 'PREMIS_CD', 'PREMIS_DESC', 'WEAPON_USED_CD',
#        'WEAPON_DESC', 'STATUS', 'STATUS_DESC', 'LOCATION'],
#       dtype='object')
# Index(['Neighborhood', 'American Indian and Alaska Native', 'Asian',
#        'African American', 'Native Hawaiian and Other Pacific Islander',
#        'White', 'Some Other Race', 'Two or More Races', 'Hispanic or Latino'],
#       dtype='object')

# %%
# rename la_population["Total Population"] to all lower case to match la_crime_data column name
la_population = la_population.rename(columns={"Neighborhood" : "AREA_NAME"})

# %%
la_crime_data_unique = la_crime_data['AREA_NAME'].unique()

la_crime_data_unique
# Out:
# array(['Harbor', 'Southwest', 'West Valley', 'Devonshire', 'Mission',
#        'Topanga', 'Hollenbeck', 'Southeast', 'Foothill', 'West LA',
#        'Northeast', 'Olympic', 'Newton', '77th Street', 'Central',
#        'Van Nuys', 'N Hollywood', 'Pacific', 'Rampart', 'Wilshire',
#        'Hollywood'], dtype=object)

# %%
la_population_unique = la_population["AREA_NAME"].unique()

la_population_unique
# Out:
# array(['City of L.A.', 'Adams-Normandie', 'Arleta', 'Arlington Heights',
#        'Arlington Park', 'Atwater Village', 'Baldwin Hills', 'Bel Air',
#        'Beverly Crest', 'Beverly Glen', 'Beverlywood', 'Boyle Heights',
#        'Brentwood', 'Broadway-Manchester', 'Byzantine-Latino Quarter',
#        'Cahuenga Pass', 'Canoga Park', 'Carthay Circle',
#        'Central-Alameda', 'Century City', 'Century Cove', 'Century Palms',
#        'Chatsworth', 'Cheviot Hills', 'Chinatown & Historic L.A.',
#        'Country Club Park', 'Crenshaw', 'Cypress Park', 'Del Rey',
#        'Downtown', 'Eagle Rock', 'East Hollywood', 'Echo Park',
#        'El Sereno', 'Elysian Park', 'Elysian Valley', 'Encino',
#        'Exposition Park', 'Fairfax', 'Figueroa Park Square',
#        'Florence (LA)', 'Glassell Park', 'Gramercy Park', 'Granada Hills',
#        'Green Meadows', 'Griffith Park/Los Feliz', 'Hancock Park',
#        'Hansen Dam Rec Area', 'Harbor City', 'Harbor Gateway',
#        'Harvard Heights', 'Hermon', 'Highland Park',
#        'Historic South Central', 'Historic West Adams', 'Hollwood Hills',
#        'Hollywood', 'Hyde Park', 'Jefferson Park', 'King Estates',
#        'Koreatown', 'La Tuna Canyon', 'Lake Balboa', 'Lakeview Terrace',
#        'Larchmont Village', "Larchmont-St. Andrew's Square",
#        'Leimert Park', 'Lincoln Heights', 'Manchester Square',
#        'Maplewood-St. Andrews', 'Mar Vista', 'Marina', 'Melrose',
#        'Mid-City', 'Mid-City West', 'Mid-Wilshire (Brookside)',
#        'Mid-Wilshire (Fremont Place-Windsor Village)',
#        'Mid-Wilshire (Wilshire Park)', 'Miracle Mile', 'Mission Hills',
#        'Montecito Heights', 'Monterey Hills', 'Mt. Washington',
#        'North Hills', 'North Hollywood', 'Northridge', 'Olympic Park',
#        'Pacific Palisades', 'Pacoima', 'Palms', 'Panorama City',
#        'Picfair Village', 'Pico Park', 'Pico-Union', 'Playa del Rey',
#        'Playa Vista', 'Porter Ranch', 'Rampart Village', 'Rancho Park',
#        'Redondo Sycamore', 'Reseda', 'San Pedro',
#        'Sepulveda Dam Recreation Area', 'Shadow Hills', 'Sherman Oaks',
#        'Silver Lake', 'South Carthay', 'South Park', 'South Robertson',
#        'Studio City', 'Sun Valley', 'Sunland', 'Sycamore Grove', 'Sylmar',
#        'Tarzana', 'Terminal Island', 'Toluca Lake', 'Toluca Woods',
#        'Topanga State Park', 'Tujunga', 'University Expo Park West',
#        'University Hills', 'University Park', 'Valley Glen',
#        'Valley Village', 'Van Nuys', 'Venice', 'Vermont Knolls',
#        'Vermont Square',
#        'Vermont-Slauson/Harvard Park/Chesterfield Square',
#        'Vermont Vista', 'View Heights', 'Virgil Village', 'Watts',
#        'West Adams', 'West Adams Terrace/Kinney Heights/Berkely Square',
#        'West Hills', 'West LA', 'West Toluca Lake', 'Westchester',
#        'Western Heights/Sugar Hill/West Adams Heights', 'Western Wilton',
#        'Westlake & Historic Filipinotown', 'Westside Village', 'Westwood',
#        'Wilmington', 'Wilshire Center', 'Wilshire Vista',
#        'Wilshire Vista Heights', 'Windsor Square', 'Winnetka',
#        'Woodland Hills'], dtype=object)

# %%
la_population['AREA_NAME'] = la_population['AREA_NAME'].apply(lambda x: 'Harbor' if 'Harbor' in x else x)

# %%
la_population['AREA_NAME'] = la_population['AREA_NAME'].replace('North Hollywood', 'N Hollywood')

# %%
# southwest 

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Adams-Normandie','West Adams','West Adams Terrace/Kinney Heights/Berkely Square', 'University Expo Park West', 
                                                                'Vermont Square','Vermont-Slauson/Harvard Park/Chesterfield Square', 'Baldwin Hills', 'Crenshaw', 'Broadway-Manchester',
                                                                'Central-Alameda', 'Exposition Park', 'Florence (LA)', 'Historic South Central', 'Hyde Park', 'Leimert Park','Gramercy Park',
                                                                'Manchester Square', 'South Park', 'Vermont Vista', 'Watts', 'Vermont Knolls', 'Historic West Adams', 'South Robertson'], 'Southwest')

# %%
# west valley

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['West Hills', 'Canoga Park','Woodland Hills','Reseda',
                                                                'Arleta','Encino', 'Tarzana','Valley Village',
                                                                 'Pacoima','Sherman Oaks','Sunland','Sepulveda Dam Recreation Area',
                                                                 'Studio City', 'Winnetka','Valley Glen'], 'West Valley')

# %%
# southeast 

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Green Meadows','Toluca Lake', 'Toluca Woods', 'West Toluca Lake'], 'Southeast')

# %%
# northeast

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Atwater Village','Cypress Park','Eagle Rock','Glassell Park','Highland Park', 'Montecito Heights',
                                                                 'Mt. Washington','Hermon', 'Sycamore Grove', 'Monterey Hills'], 'Northeast')

# %%
# central 

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Koreatown','City of L.A.','Chinatown & Historic L.A.','Mid-Wilshire (Brookside)', 'Mid-Wilshire (Fremont Place-Windsor Village)',
                                                                 'Mid-Wilshire (Wilshire Park)','Hancock Park','Hollwood Hills', 'Elysian Park','Elysian Valley','Windsor Square', 'Fairfax','Picfair Village',
                                                                 'Downtown', 'South Carthay', 'Arlington Heights','Arlington Park', "Larchmont-St. Andrew's Square", 'Virgil Village', 'Country Club Park','Figueroa Park Square',
                                                                ], 'Central')

# %%
# topanga

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace('Topanga State Park', 'Topanga')

# %%
# wilshire

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Wilshire Center', 'Wilshire Vista','Wilshire Vista Heights','Wilshire', 'Mid-City', 
                                                                 'Mid-City West', 'Maplewood-St. Andrews', 'Miracle Mile', 'Western Wilton', 'Carthay Circle'], 'Wilshire')

# %%
# pacific 

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Redondo Sycamore', 'Pacific Palisades','Playa Vista','Bel Air',
                                                                'Brentwood','Century City', 'Century Cove', 'Century Palms','Cheviot Hills','Marina',
                                                                'Mar Vista','Palms','Rancho Park', 'Playa del Rey', 'Westchester', 'Del Rey'], 'Pacific')

# %%
# harbor

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Harbor','San Pedro','Wilmington', 'Terminal Island'], 'Harbor')

# %%
# devonshire

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Granada Hills','Chatsworth', 'Porter Ranch', 'Northridge'], 'Devonshire')

# %%
# mission 

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Mission Hills','North Hills','Panorama City','Sylmar'], 'Mission')

# %%
# hollenbeck 

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Boyle Heights','University Hills','Lincoln Heights','El Sereno'], 'Hollenbeck')

# %%
# foothill 


la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Lakeview Terrace','Shadow Hills','Tujunga', 'Sun Valley', 'La Tuna Canyon', 'Hansen Dam Rec Area'], 'Foothill')

# %%
# rampart

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Silver Lake','Echo Park','Pico-Union','Pico Park','Westlake & Historic Filipinotown', 'Byzantine-Latino Quarter', 'Rampart Village'], 'Rampart')

# %%
# west LA
la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Westwood','Venice', 'Beverly Crest','Beverly Glen', 'Beverlywood',
                                                                'Westside Village', 'South Robertson'],'West LA')

# %%
# olympic

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['University Park','Harvard Heights','Jefferson Park', 'Olympic Park',], 'Olympic')

# %%
# newton


la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Western Heights/Sugar Hill/West Adams Heights', 'View Heights'], 'Newton')

# %%
# hollywood 

la_population['AREA_NAME'] = la_population['AREA_NAME'].replace(['Hollywood', 'Melrose', 'Griffith Park/Los Feliz', 
                                                                 'King Estates','Larchmont Village', 'Cahuenga Pass', 'East Hollywood'], 'Hollywood')

# %%
# Van Nuys
la_population['AREA_NAME'] = la_population['AREA_NAME'].replace('Lake Balboa', 'Van Nuys')

# %%
# 77th street
# this will be dropped due to the road going through multiple divisions, 
# and the location of the crime reported is not the exact location due to confidentiality.

# %%
la_population_unique = la_population['AREA_NAME'].unique()

la_population_unique
# Out:
# array(['Central', 'Southwest', 'West Valley', 'Northeast', 'Pacific',
#        'West LA', 'Hollenbeck', 'Rampart', 'Hollywood', 'Wilshire',
#        'Devonshire', 'Southeast', 'Foothill', 'Harbor', 'Olympic',
#        'Van Nuys', 'Mission', 'N Hollywood', 'Topanga', 'Newton'],
#       dtype=object)

# %%
print(len(la_population_unique))
# Out:
# 20

# %%
matching_areas = la_crime_data[la_crime_data['AREA_NAME'].isin(la_population['AREA_NAME'])]


matching_areas
# Out:
#             DR_NO   DATE_RPTD    DATE_OCC  AREA    AREA_NAME  RPT_DIST_NO  \
# 0       250504239  2025-03-13  2025-03-13     5       Harbor          516
# 1       250504238  2025-03-13  2025-03-13     5       Harbor          569
# 2       250304275  2025-03-13  2025-03-13     3    Southwest          338
# 3       251000503  2025-03-13  2025-03-13    10  West Valley         1035
# 4       251700501  2025-03-13  2025-03-13    17   Devonshire         1717
# ...           ...         ...         ...   ...          ...          ...
# 127821  241304040  2024-01-01  2024-01-01    13       Newton         1385
# 127822  240709471  2024-01-01  2024-01-01     7     Wilshire          721
# 127823  241104022  2024-01-01  2024-01-01    11    Northeast         1184
# 127824  240504085  2024-01-01  2024-01-01     5       Harbor          569
# 127825  242004536  2024-01-01  2024-01-01    20      Olympic         2025
#
#         CRM_CD                                        CRM_CD_DESC  \
# 0          510                                   VEHICLE - STOLEN
# 1          440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 2          510                                   VEHICLE - STOLEN
# 3          624                           BATTERY - SIMPLE ASSAULT
# 4          930             CRIMINAL THREATS - NO WEAPON DISPLAYED
# ...        ...                                                ...
# 127821     626                  INTIMATE PARTNER - SIMPLE ASSAULT
# 127822     815                SEXUAL PENETRATION W/FOREIGN OBJECT
# 127823     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 127824     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 127825     330                              BURGLARY FROM VEHICLE
#
#                               MOCODES VICT_AGE VICT_SEX VICT_DESCENT  \
# 0                             Unknown        X        X            X
# 1                             Unknown        X        X            X
# 2                             Unknown        X        X            X
# 3            0913 1815 1251 0400 0416       16        M            H
# 4                 0340 0359 1822 1259       16        M            H
# ...                               ...      ...      ...          ...
# 127821            0400 0913 1813 2000       43        F            H
# 127822                      1822 0515       69        F            W
# 127823  1234 1822 0408 0429 0416 0444       43        M            H
# 127824                      0329 0311        X        X            X
# 127825                      1822 0344       40        F            A
#
#        PREMIS_CD                         PREMIS_DESC       WEAPON_USED_CD  \
# 0          108.0                         PARKING LOT  Unknown / None Used
# 1          101.0                              STREET  Unknown / None Used
# 2          101.0                              STREET  Unknown / None Used
# 3          721.0                         HIGH SCHOOL                400.0
# 4          101.0                              STREET                511.0
# ...          ...                                 ...                  ...
# 127821     501.0              SINGLE FAMILY DWELLING                400.0
# 127822     701.0                            HOSPITAL                400.0
# 127823     207.0              BAR/COCKTAIL/NIGHTCLUB                400.0
# 127824     506.0  ABANDONED BUILDING ABANDONED HOUSE  Unknown / None Used
# 127825     123.0        PARKING UNDERGROUND/BUILDING  Unknown / None Used
#
#                                            WEAPON_DESC STATUS  STATUS_DESC  \
# 0                                  Unknown / None Used     IC  Invest Cont
# 1                                  Unknown / None Used     IC  Invest Cont
# 2                                  Unknown / None Used     IC  Invest Cont
# 3       STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 4                                        VERBAL THREAT     IC  Invest Cont
# ...                                                ...    ...          ...
# 127821  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 127822  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 127823  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 127824                             Unknown / None Used     IC  Invest Cont
# 127825                             Unknown / None Used     IC  Invest Cont
#
#                                         LOCATION
# 0        1300 N  FRIES                        AV
# 1                                       BERTH 73
# 2        3100    MCCLINTOCK                   AV
# 3       18200    KITTRIDGE                    ST
# 4       11200    GOTHIC                       AV
# ...                                          ...
# 127821    400 E  60TH                         ST
# 127822   8700 W  BEVERLY                      BL
# 127823   1400 W  SUNSET                       BL
# 127824   2500    SIGNAL                       ST
# 127825    300 S  MARIPOSA                     AV
#
# [121046 rows x 19 columns]

# %%
la_population['AREA_NAME'].unique()
# Out:
# array(['Central', 'Southwest', 'West Valley', 'Northeast', 'Pacific',
#        'West LA', 'Hollenbeck', 'Rampart', 'Hollywood', 'Wilshire',
#        'Devonshire', 'Southeast', 'Foothill', 'Harbor', 'Olympic',
#        'Van Nuys', 'Mission', 'N Hollywood', 'Topanga', 'Newton'],
#       dtype=object)

# %%
print(len(la_population['AREA_NAME'].unique()))
# Out:
# 20

# %%
# Find the unique values in la_poulation that are not in la_crime_data
unique_in_la_population = la_population[~la_population['AREA_NAME'].isin(la_crime_data['AREA_NAME'])]

unique_in_la_population
# Out:
# Empty DataFrame
# Columns: [AREA_NAME, American Indian and Alaska Native, Asian, African American, Native Hawaiian and Other Pacific Islander, White, Some Other Race, Two or More Races, Hispanic or Latino, Total Population]
# Index: []

# %%
unique_in_la_crime_data = la_crime_data[~la_crime_data['AREA_NAME'].isin(la_population['AREA_NAME'])]

unique_in_la_crime_data
# Out:
#             DR_NO   DATE_RPTD    DATE_OCC  AREA    AREA_NAME  RPT_DIST_NO  \
# 83      251204190  2025-02-14  2025-02-14    12  77th Street         1239
# 162     251204137  2025-01-31  2025-01-31    12  77th Street         1207
# 210     251204103  2025-01-22  2025-01-22    12  77th Street         1259
# 226     251204086  2025-01-16  2025-01-16    12  77th Street         1269
# 253     251204039  2025-01-01  2025-01-01    12  77th Street         1258
# ...           ...         ...         ...   ...          ...          ...
# 127734  241204065  2024-01-01  2024-01-01    12  77th Street         1268
# 127764  241204043  2024-01-01  2024-01-01    12  77th Street         1209
# 127803  241204086  2024-01-01  2024-01-01    12  77th Street         1239
# 127806  241204067  2024-01-01  2024-01-01    12  77th Street         1268
# 127816  241204023  2024-01-01  2024-01-01    12  77th Street         1269
#
#         CRM_CD                                     CRM_CD_DESC  \
# 83         930          CRIMINAL THREATS - NO WEAPON DISPLAYED
# 162        230  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 210        510                                VEHICLE - STOLEN
# 226        510                                VEHICLE - STOLEN
# 253        946                       OTHER MISCELLANEOUS CRIME
# ...        ...                                             ...
# 127734     236           INTIMATE PARTNER - AGGRAVATED ASSAULT
# 127764     210                                         ROBBERY
# 127803     761                                 BRANDISH WEAPON
# 127806     624                        BATTERY - SIMPLE ASSAULT
# 127816     236           INTIMATE PARTNER - AGGRAVATED ASSAULT
#
#                                         MOCODES VICT_AGE VICT_SEX  \
# 83           1258 1822 0305 0444 0319 0421 1251       13        M
# 162     1258 0302 0216 0213 0202 0443 1251 1822       10        M
# 210                                     Unknown        X        X
# 226                                     Unknown        X        X
# 253                                     Unknown        X        X
# ...                                         ...      ...      ...
# 127734                 0400 0416 2000 1814 0913       19        F
# 127764       0344 1822 0216 0443 0341 0370 1218       43        M
# 127803       0334 0329 0361 0913 0421 0432 0445       56        M
# 127806                      0400 0416 0913 0561       41        F
# 127816                 2000 1814 0913 0408 2034       29        F
#
#        VICT_DESCENT PREMIS_CD             PREMIS_DESC       WEAPON_USED_CD  \
# 83                B     124.0                BUS STOP                511.0
# 162               B     704.0       ELEMENTARY SCHOOL                104.0
# 210               X     101.0                  STREET  Unknown / None Used
# 226               X     108.0             PARKING LOT  Unknown / None Used
# 253               X     726.0         POLICE FACILITY  Unknown / None Used
# ...             ...       ...                     ...                  ...
# 127734            B     501.0  SINGLE FAMILY DWELLING                400.0
# 127764            H     101.0                  STREET                500.0
# 127803            H     501.0  SINGLE FAMILY DWELLING                310.0
# 127806            B     501.0  SINGLE FAMILY DWELLING                400.0
# 127816            H     501.0  SINGLE FAMILY DWELLING                400.0
#
#                                            WEAPON_DESC STATUS   STATUS_DESC  \
# 83                                       VERBAL THREAT     IC   Invest Cont
# 162                                            SHOTGUN     IC   Invest Cont
# 210                                Unknown / None Used     IC   Invest Cont
# 226                                Unknown / None Used     IC   Invest Cont
# 253                                Unknown / None Used     IC   Invest Cont
# ...                                                ...    ...           ...
# 127734  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AA  Adult Arrest
# 127764                     UNKNOWN WEAPON/OTHER WEAPON     IC   Invest Cont
# 127803                            CONCRETE BLOCK/BRICK     AA  Adult Arrest
# 127806  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC   Invest Cont
# 127816  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AA  Adult Arrest
#
#                                        LOCATION
# 83      6000 S  VERMONT                      AV
# 162      800 W  51ST                         ST
# 210     7800    MCKINLEY                     AV
# 226     8500    TOWNE                        AV
# 253                            7600 S  BROADWAY
# ...                                         ...
# 127734   100 W  82ND                         ST
# 127764                                 FIGUEROA
# 127803   600 W  61ST                         ST
# 127806   100 W  82ND                         ST
# 127816   400 E  84TH                         ST
#
# [6780 rows x 19 columns]

# %%
la_crime_data = la_crime_data.drop(la_crime_data[la_crime_data['AREA_NAME'].str.lower() == '77th street'].index)

# %%
la_crime_data.shape
# Out:
# (121046, 19)

# %%
la_crime_data.columns
# Out:
# Index(['DR_NO', 'DATE_RPTD', 'DATE_OCC', 'AREA', 'AREA_NAME', 'RPT_DIST_NO',
#        'CRM_CD', 'CRM_CD_DESC', 'MOCODES', 'VICT_AGE', 'VICT_SEX',
#        'VICT_DESCENT', 'PREMIS_CD', 'PREMIS_DESC', 'WEAPON_USED_CD',
#        'WEAPON_DESC', 'STATUS', 'STATUS_DESC', 'LOCATION'],
#       dtype='object')

# %%
la_population.shape
# Out:
# (152, 10)

# %%
la_population.columns
# Out:
# Index(['AREA_NAME', 'American Indian and Alaska Native', 'Asian',
#        'African American', 'Native Hawaiian and Other Pacific Islander',
#        'White', 'Some Other Race', 'Two or More Races', 'Hispanic or Latino',
#        'Total Population'],
#       dtype='object')

# %%
print(la_population['AREA_NAME'].duplicated().sum())
# Out:
# 132

# %%
la_population
# Out:
#        AREA_NAME  American Indian and Alaska Native   Asian  African American  \
# 0        Central                              44777  463960            328445
# 1      Southwest                                129     394               783
# 2    West Valley                                452    4430               181
# 3        Central                                121    1919              2293
# 4        Central                                 68      32              1169
# ..           ...                                ...     ...               ...
# 147     Wilshire                                  9     109               278
# 148     Wilshire                                  0     243               717
# 149      Central                                  0    1246               109
# 150  West Valley                                694   13114              2999
# 151  West Valley                                477    9874              5559
#
#      Native Hawaiian and Other Pacific Islander    White  Some Other Race  \
# 0                                          5627  1092687           967895
# 1                                            63      663             2673
# 2                                            46     2958            12733
# 3                                             0      744             5048
# 4                                             0      122              929
# ..                                          ...      ...              ...
# 147                                           0      831              308
# 148                                           0      937              459
# 149                                           0      794              100
# 150                                          46    23594            20575
# 151                                         180    45874             6049
#
#      Two or More Races  Hispanic or Latino  Total Population
# 0               607324             1822163           5332878
# 1                  944                4783             10432
# 2                 7266               25861             53927
# 3                 1755                8195             20075
# 4                   95                1508              3923
# ..                 ...                 ...               ...
# 147                576                 407              2518
# 148                263                 672              3291
# 149                481                 362              3092
# 150               9824               31335            102181
# 151               9037               13642             90692
#
# [152 rows x 10 columns]

# %%
la_population = la_population.groupby('AREA_NAME').sum().reset_index()

# %%
la_population.shape
# Out:
# (20, 10)

# %%
population_crime_df = pd.merge(la_crime_data, la_population, on="AREA_NAME", how="left")

# %%
display(population_crime_df)
# Out:
#             DR_NO   DATE_RPTD    DATE_OCC  AREA    AREA_NAME  RPT_DIST_NO  \
# 0       250504239  2025-03-13  2025-03-13     5       Harbor          516
# 1       250504238  2025-03-13  2025-03-13     5       Harbor          569
# 2       250304275  2025-03-13  2025-03-13     3    Southwest          338
# 3       251000503  2025-03-13  2025-03-13    10  West Valley         1035
# 4       251700501  2025-03-13  2025-03-13    17   Devonshire         1717
# ...           ...         ...         ...   ...          ...          ...
# 121041  241304040  2024-01-01  2024-01-01    13       Newton         1385
# 121042  240709471  2024-01-01  2024-01-01     7     Wilshire          721
# 121043  241104022  2024-01-01  2024-01-01    11    Northeast         1184
# 121044  240504085  2024-01-01  2024-01-01     5       Harbor          569
# 121045  242004536  2024-01-01  2024-01-01    20      Olympic         2025
#
#         CRM_CD                                        CRM_CD_DESC  \
# 0          510                                   VEHICLE - STOLEN
# 1          440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 2          510                                   VEHICLE - STOLEN
# 3          624                           BATTERY - SIMPLE ASSAULT
# 4          930             CRIMINAL THREATS - NO WEAPON DISPLAYED
# ...        ...                                                ...
# 121041     626                  INTIMATE PARTNER - SIMPLE ASSAULT
# 121042     815                SEXUAL PENETRATION W/FOREIGN OBJECT
# 121043     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 121044     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 121045     330                              BURGLARY FROM VEHICLE
#
#                               MOCODES VICT_AGE  ...  \
# 0                             Unknown        X  ...
# 1                             Unknown        X  ...
# 2                             Unknown        X  ...
# 3            0913 1815 1251 0400 0416       16  ...
# 4                 0340 0359 1822 1259       16  ...
# ...                               ...      ...  ...
# 121041            0400 0913 1813 2000       43  ...
# 121042                      1822 0515       69  ...
# 121043  1234 1822 0408 0429 0416 0444       43  ...
# 121044                      0329 0311        X  ...
# 121045                      1822 0344       40  ...
#
#                                         LOCATION  \
# 0        1300 N  FRIES                        AV
# 1                                       BERTH 73
# 2        3100    MCCLINTOCK                   AV
# 3       18200    KITTRIDGE                    ST
# 4       11200    GOTHIC                       AV
# ...                                          ...
# 121041    400 E  60TH                         ST
# 121042   8700 W  BEVERLY                      BL
# 121043   1400 W  SUNSET                       BL
# 121044   2500    SIGNAL                       ST
# 121045    300 S  MARIPOSA                     AV
#
#        American Indian and Alaska Native  Asian African American  \
# 0                                   1689  19777            14606
# 1                                   1689  19777            14606
# 2                                   8949  13176           135099
# 3                                   4482  68900            30270
# 4                                   1938  41598            10827
# ...                                  ...    ...              ...
# 121041                                36    797             3271
# 121042                              1669  32237            13757
# 121043                              3766  26109             2644
# 121044                              1689  19777            14606
# 121045                               437  10357             6158
#
#        Native Hawaiian and Other Pacific Islander   White Some Other Race  \
# 0                                             669   35988           42779
# 1                                             669   35988           42779
# 2                                             755   38986          212898
# 3                                             729  285533          128171
# 4                                             321   80569           28667
# ...                                           ...     ...             ...
# 121041                                          0     673            1456
# 121042                                        117   34523           31395
# 121043                                         33   40412           36598
# 121044                                        669   35988           42779
# 121045                                         32    9357           15391
#
#        Two or More Races Hispanic or Latino  Total Population
# 0                  35622             123570            274700
# 1                  35622             123570            274700
# 2                 103916             371954            885733
# 3                 103957             250663            872705
# 4                  26983              60021            250924
# ...                  ...                ...               ...
# 121041               505               1710              8448
# 121042             16778              51830            182306
# 121043             29174              73905            212641
# 121044             35622             123570            274700
# 121045              8650              29392             79774
#
# [121046 rows x 28 columns]

# %% [markdown]
# #AREA_NAMES repeat due to the multiple neighborhoods within the same division. Need to leave them as be to count all of the instances a particular crime that is committed against a certain demographic within each division, and compare the amount and type of crimes that occured within the first 3 months of 2024 and 2025. Wanted to start the integration of my 2 datasets for the proposal and further analysis will be completed later on.

# %%
population_crime_df.shape
# Out:
# (121046, 28)

# %%
merged_dataframe = population_crime_df.to_csv('crime_population_merged.csv', index=False)
